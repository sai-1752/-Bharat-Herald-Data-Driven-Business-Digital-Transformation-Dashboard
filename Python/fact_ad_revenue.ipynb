# %%
import pandas as pd
df_fact_ad_revenue = pd.read_csv("/Volumes/workspace/default/dataset/fact_ad_revenue.csv")
print(df_fact_ad_revenue)
# Out:
#     edition_id ad_category  ... currency              comments
# 0       ED1005        A001  ...      EUR                   NaN
# 1       ED1005        A002  ...      USD                   NaN
# 2       ED1001        A003  ...      INR                   NaN
# 3       ED1003        A002  ...      USD                   NaN
# 4       ED1007        A003  ...      USD                   NaN
# ..         ...         ...  ...      ...                   ...
# 715     ED1001        A004  ...      INR                   NaN
# 716     ED1002        A004  ...      INR                   NaN
# 717     ED1004        A001  ...      USD                   NaN
# 718     ED1007        A002  ...      INR                   NaN
# 719     ED1002        A003  ...      USD  Real estate slowdown
#
# [720 rows x 6 columns]

# %%
df_fact_ad_revenue = df_fact_ad_revenue.fillna({'comments': 'No Comment'})
display(
    df_fact_ad_revenue
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_fact_ad_revenue = df_fact_ad_revenue.replace(
    {'currency': {'IN RUPEES': 'INR'}}
)
display(
    df_fact_ad_revenue
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
